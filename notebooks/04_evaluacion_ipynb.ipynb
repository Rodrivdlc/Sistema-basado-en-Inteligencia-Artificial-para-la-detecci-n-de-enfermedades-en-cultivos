# %% [markdown]
# <a href="https://colab.research.google.com/github/Rodrivdlc/Sistema-basado-en-Inteligencia-Artificial-para-la-detecci-n-de-enfermedades-en-cultivos/blob/main/notebooks/04_evaluacion_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import json
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow import keras
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
model = keras.models.load_model(
    "/content/drive/MyDrive/TFG/models/modelo_tomate_mobilenetv2_finetuned.keras"
)

# %%
with open(
    "/content/drive/MyDrive/TFG/models/class_names.json",
    "r"
) as f:
    class_names = json.load(f)

print(class_names)
# Out:
# ['Tomato_Bacterial_spot', 'Tomato_Early_blight', 'Tomato_Late_blight', 'Tomato_Leaf_Mold', 'Tomato_Septoria_leaf_spot', 'Tomato_Spider_mites_Two_spotted_spider_mite', 'Tomato__Target_Spot', 'Tomato__Tomato_YellowLeaf__Curl_Virus', 'Tomato__Tomato_mosaic_virus', 'Tomato_healthy']

# %%
def predecir_imagen(ruta_imagen):
    img = tf.keras.utils.load_img(
        ruta_imagen,
        target_size=(224, 224)
    )

    img_array = tf.keras.utils.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0)

    predicciones = model.predict(img_array, verbose=0)

    indice = np.argmax(predicciones[0])
    confianza = predicciones[0][indice]

    clase = class_names[indice]

    return clase, confianza

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-ab41875a-f315-4780-981a-76d45109e613" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ab41875a-f315-4780-981a-76d45109e613">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
ruta = "1-29.png"

clase, confianza = predecir_imagen(ruta)

print("Predicción:", clase)
print(f"Confianza: {confianza * 100:.2f}%")
# Out:
# Predicción: Tomato__Tomato_YellowLeaf__Curl_Virus
# Confianza: 98.83%

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-58a26441-7c94-4f84-ab93-dc3b72fadc48" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-58a26441-7c94-4f84-ab93-dc3b72fadc48">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
ruta = "2.jpg"

clase, confianza = predecir_imagen(ruta)

print("Predicción:", clase)
print(f"Confianza: {confianza * 100:.2f}%")
# Out:
# Predicción: Tomato_Early_blight
# Confianza: 48.54%

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-85a35b83-6a79-4b37-a9eb-64aaf83344ac" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-85a35b83-6a79-4b37-a9eb-64aaf83344ac">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
ruta = "h.JPG"

clase, confianza = predecir_imagen(ruta)

print("Predicción:", clase)
print(f"Confianza: {confianza * 100:.2f}%")
# Out:
# Predicción: Tomato_healthy
# Confianza: 100.00%
